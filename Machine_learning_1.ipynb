# %% [markdown]
# <a href="https://colab.research.google.com/github/SaimKhan9/Assignment_BPE/blob/main/Machine_learning_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/modified_placement_data.csv')

# %%
df.head()
# Out:
#   cgpa     iq placement
# 0  6,8  123.0       Yes
# 1  5,9  106.0        No
# 2  5,3  121.0        No
# 3  7,4  132.0       Yes
# 4  5,8  142.0        No
